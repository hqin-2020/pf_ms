# %%
import os
import pickle

with open('Run_Aso1_0_CPU.py') as f:
    lines = f.readlines()

# %%
lines
# Out:
# ['import numpy as np\n',
#  'import scipy as sp\n',
#  'import pandas as pd\n',
#  'import matplotlib.pyplot as plt\n',
#  'import seaborn as sns\n',
#  'import time\n',
#  'from tqdm import tqdm\n',
#  'import multiprocessing\n',
#  'import pickle\n',
#  'import os\n',
#  '\n',
#  'from PF_Aso1_0_CPU import *\n',
#  '\n',
#  "if __name__ == '__main__':\n",
#  '\n',
#  '    workdir = os.path.dirname(os.getcwd())\n',
#  '    srcdir = os.getcwd()\n',
#  "    datadir = workdir + '/data/'\n",
#  "    outputdir = '/scratch/qhaomin/pf_ms/'\n",
#  '\n',
#  '    seed = 6\n',
#  '\n',
#  "    obs_series = pd.read_csv(datadir + 'data.csv', delimiter=',')\n",
#  '    obs_series = np.array(obs_series.iloc[:,1:]).T\n',
#  '\n',
#  '    T = obs_series.shape[1]\n',
#  '    N = 100_000\n',
#  '\n',
#  "    case = 'actual data, seed = ' + str(seed) + ', T = ' + str(T) + ', N = ' + str(N)\n",
#  '    try: \n',
#  "        casedir = outputdir + case  + '/'\n",
#  '        os.mkdir(casedir)\n',
# ...

# %%
for block in range(1,35):
    for i in range(len(lines)):
        if lines[i].startswith('    seed = '):
            lines[i] = '    seed = '+str(block+100) + '\n'
    with open('Run_Aso1_0_CPU_'+str(block)+'.py', 'w') as f:
        f.writelines(lines)

# %%
import numpy as np
np.random.seed(1.2)

# %%
# %%time
a = []
for i in range(10_000_000):
    a.append([np.array([1,2]),np.array([1,2,3]),np.array([1,2,4]),np.array([1,2,5])])
# Out:
# CPU times: user 31.8 s, sys: 9.2 s, total: 41 s
# Wall time: 45.5 s

# %%
# %%time

[i[0] for i in a]
[i[1] for i in a]
[i[2] for i in a]
lsp = [i[3] for i in a]
# Out:
# CPU times: user 346 ms, sys: 20.7 ms, total: 367 ms
# Wall time: 375 ms

# %%
from operator import itemgetter

# %%
# %%time
list(map(itemgetter(0), a))
list(map(itemgetter(1), a))
list(map(itemgetter(2), a))
list(map(itemgetter(3), a))
# Out:
# CPU times: user 291 ms, sys: 19.1 ms, total: 310 ms
# Wall time: 308 ms
# [array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
#  array([1, 2, 5]),
# ...
